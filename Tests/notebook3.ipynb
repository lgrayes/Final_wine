# %%
# Dependencies
import pandas as pd

# %%
vac = pd.read_csv('../Resources/covid19_vaccinations.csv')
vac
# Out:
#     Number ABBR           State  Total_Delivered  Total_Administered  \
# 0        1   AK          Alaska           271550              183831
# 1        2   AB         Alabama           965550              612254
# 2        3   AR        Arkansas           630700              472536
# 3        4   AO  American Samoa            29450               15382
# 4        5   AZ         Arizona          1393575             1089155
# ..     ...  ...             ...              ...                 ...
# 58      59   VT         Vermont           138025              106787
# 59      60   WA      Washington          1437825             1166471
# 60      61   WI       Wisconsin          1082100              955412
# 61      62   WV   West Virginia           395600              386583
# 62      63   WY         Wyoming           122200               99099
#
#     People_with_one_Dose  People_with_2_Doses
# 0                 126381                57117
# ...

# %%
vac2 = pd.read_csv('../Resources/b2020VAERSDATA.csv')
vac2
# Out:
#        VAERS_ID  RECVDATE ABBR  AGE_YRS SEX RPT_DATE DIED DATEDIED HOSPITAL  \
# 0        855017    1/1/20   HI     55.0   F      NaN  NaN      NaN      NaN
# 1        855018    1/1/20   WI     68.0   F      NaN  NaN      NaN      NaN
# 2        855019    1/1/20  NaN     50.0   F      NaN  NaN      NaN      NaN
# 3        855020    1/1/20   TX     67.0   F      NaN  NaN      NaN      NaN
# 4        855021    1/1/20  NaN     73.0   F      NaN  NaN      NaN      NaN
# ...         ...       ...  ...      ...  ..      ...  ...      ...      ...
# 44254    918437  12/31/20   AR      NaN   F      NaN  NaN      NaN      NaN
# 44255    918438  12/31/20   AR     49.0   F      NaN  NaN      NaN      NaN
# 44256    918439  12/31/20   AR      NaN   F      NaN  NaN      NaN      NaN
# 44257    918440  12/31/20   AR      NaN   F      NaN  NaN      NaN      NaN
# 44258    918442  12/31/20   AR      NaN   F      NaN  NaN      NaN      NaN
#
# ...

# %%
# Merge two dataframes using an outer join
merge_df = pd.merge(vac, vac2, on="ABBR", how="outer")
merge_df
# Out:
#        Number ABBR   State  Total_Delivered  Total_Administered  \
# 0         1.0   AK  Alaska         271550.0            183831.0
# 1         1.0   AK  Alaska         271550.0            183831.0
# 2         1.0   AK  Alaska         271550.0            183831.0
# 3         1.0   AK  Alaska         271550.0            183831.0
# 4         1.0   AK  Alaska         271550.0            183831.0
# ...       ...  ...     ...              ...                 ...
# 46821     NaN   Ar     NaN              NaN                 NaN
# 46822     NaN   PW     NaN              NaN                 NaN
# 46823     NaN   PW     NaN              NaN                 NaN
# 46824     NaN   Co     NaN              NaN                 NaN
# 46825     NaN   AS     NaN              NaN                 NaN
#
#        People_with_one_Dose  People_with_2_Doses  VAERS_ID  RECVDATE  AGE_YRS  \
# 0                  126381.0              57117.0  855962.0    1/9/20     59.0
# ...

# %%
# Remove the rows with missing data
clean_vac_df = merge_df.dropna(how="any")
clean_vac_df.count()
# Out:
# Number                  0
# ABBR                    0
# State                   0
# Total_Delivered         0
# Total_Administered      0
# People_with_one_Dose    0
# People_with_2_Doses     0
# VAERS_ID                0
# RECVDATE                0
# AGE_YRS                 0
# SEX                     0
# RPT_DATE                0
# DIED                    0
# DATEDIED                0
# HOSPITAL                0
# HOSPDAYS                0
# DISABLE                 0
# RECOVD                  0
# VAX_DATE                0
# ONSET_DATE              0
# NUMDAYS                 0
# dtype: int64

# %%
clean_vac_df.head()
# Out:
# Empty DataFrame
# Columns: [Number, ABBR, State, Total_Delivered, Total_Administered, People_with_one_Dose, People_with_2_Doses, VAERS_ID, RECVDATE, AGE_YRS, SEX, RPT_DATE, DIED, DATEDIED, HOSPITAL, HOSPDAYS, DISABLE, RECOVD, VAX_DATE, ONSET_DATE, NUMDAYS]
# Index: []
#
# [0 rows x 21 columns]

# %%
clean_vac_df.tail()
# Out:
#       Number ABBR          State  Total_Delivered  Total_Administered  \
# 2680    54.0   TX          Texas        5099325.0           4133747.0
# 2839    60.0   WA     Washington        1437825.0           1166471.0
# 2850    61.0   WI      Wisconsin        1082100.0            955412.0
# 2885    61.0   WI      Wisconsin        1082100.0            955412.0
# 2916    62.0   WV  West Virginia         395600.0            386583.0
#
#       People_with_one_Dose  People_with_2_Doses   VAERS_ID RECVDATE  AGE_YRS  \
# 2680             2970596.0            1159996.0   963235.0  1/21/21     94.0
# 2839              870853.0             281718.0  1002636.0   2/4/21     90.0
# 2850              709908.0             234709.0   927260.0   1/7/21     87.0
# 2885              709908.0             234709.0   975002.0  1/26/21     88.0
# 2916              247689.0             138882.0  1002808.0   2/4/21     90.0
#
#      SEX DIED DATEDIED  HOSPDAYS  VAX_DATE ONSET_DATE  NUMDAYS  FORM_VERS  \
# ...

# %%
# Count for each state
state_counts = clean_vac_df["ABBR"].value_counts()
state_counts
# Out:
# MI    8
# CO    4
# FL    4
# NC    4
# MA    4
# OH    3
# NY    3
# AR    3
# CA    2
# NH    2
# TX    2
# AZ    2
# NE    2
# ND    2
# WI    2
# MN    2
# IL    1
# WA    1
# NJ    1
# OR    1
# KS    1
# SC    1
# MT    1
# WV    1
# GA    1
# IA    1
# Name: ABBR, dtype: int64

# %%
# Using GroupBy in order to separate the data into fields according to "state" values
grouped_vac_df = clean_vac_df.groupby(['ABBR'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_vac_df)

# In order to be visualized, a data function must be used...
grouped_vac_df.count()
# Out:
# ...
#       Number  State  Total_Delivered  Total_Administered  \
# ABBR
# AR         3      3                3                   3
# AZ         2      2                2                   2
# CA         2      2                2                   2
# CO         4      4                4                   4
# FL         4      4                4                   4
# GA         1      1                1                   1
# IA         1      1                1                   1
# IL         1      1                1                   1
# KS         1      1                1                   1
# MA         4      4                4                   4
# MI         8      8                8                   8
# MN         2      2                2                   2
# MT         1      1                1                   1
# NC         4      4                4                   4
# ND         2      2                2                   2
# ...

# %%
# Remove extra columns

del grouped_vac_df['State']
grouped_vac_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-d4be4a025f76> in <module>()
#       1 # Remove extra columns
#       2
# ----> 3 del grouped_vac_df['State']
#       4 grouped_vac_df
#
# TypeError: 'DataFrameGroupBy' object does not support item deletion
