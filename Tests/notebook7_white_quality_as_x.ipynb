# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

from sklearn.ensemble import RandomForestClassifier

# %%
df_white = pd.read_csv('../Resources/winequality-white.csv')
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(df_white, kind='reg')
plt.savefig('output_white.png')

# %%
sns.lmplot(x="quality", y="fixed acidity", data = df_white)
plt.savefig('white_quality_fixed_acidity.png')

# %%
sns.lmplot(x="quality", y="volatile acidity", data = df_white)
plt.savefig('white_quality_volatile_acidity.png')

# %%
sns.lmplot(x="quality", y="citric acid", data = df_white)
plt.savefig('white_quality_citric_acid.png')

# %%
sns.lmplot(x="quality", y="residual sugar", data = df_white)
plt.savefig('white_quality_residual_sugar.png')

# %%
sns.lmplot(x="quality", y="chlorides", data = df_white)
plt.savefig('white_quality_chlorides.png')

# %%
sns.lmplot(x="quality", y="free sulfur dioxide", data = df_white)
plt.savefig('white_quality_free_sulfur_dioxide.png')

# %%
sns.lmplot(x="quality", y="total sulfur dioxide", data = df_white)
plt.savefig('white_quality_total_sulfur_dioxide.png')

# %%
sns.lmplot(x="quality", y="density", data = df_white)
plt.savefig('white_quality_density.png')

# %%
sns.lmplot(x="quality", y="pH", data = df_white)
plt.savefig('white_quality_pH.png')

# %%
sns.lmplot(x="quality", y="sulphates", data = df_white)
plt.savefig('white_quality_sulphates.png')

# %%
sns.lmplot(x="quality", y="alcohol", data = df_white)
plt.savefig('white_quality_alcohol.png')

# %%
sns.lmplot(x="sulphates", y="quality", data = df_white)
plt.savefig('white_sulphates_quality.png')

# %%
sns.lmplot(x="residual sugar", y="quality", data = df_white)
plt.savefig('white_sugar_quality.png')

# %%
df_white['target'] = np.where(df_white['quality']<=5,0,1)

# %%
# Assign X and y
X = dataset.drop(["quality", "target"], axis=1)
y= dataset.target
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-94d2cbca85f0> in <module>
#       1 # Assign X and y
# ----> 2 X = dataset.drop(["quality", "target"], axis=1)
#       3 y= dataset.target
#       4 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# ...
